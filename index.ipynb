# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll gain practice combining DataFrames through concatenation.  You'll also practice executing various types of joins to selectively combine the information stored in the tables!
#
# ## Objectives
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
#
#
# ## Getting Started
#
# You'll start with a quick section to gain practice with concatenating datasets using `pd.concat()`.
#
# ## Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that you have multiple DataFrames to work with, you can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
combined_df = pd.concat([df1, df2, df3])
combined_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="images/er1.png">
#
# ## Setting Join Conditions With Concatenation
#
# You can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, you'll execute an inner join. Before you do, you need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = pd.concat([df1, df4], ignore_index=False, join='inner', axis=1)
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='images/er2.png'>
#
# You'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that you can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways you can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!
#
# ## Loading In Data
# Now, it's time to move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  You'll make use of these keys to **_join_** the different tables together into a single DataFrame.  You'll also experiment with different types of joins to help us decide exactly what information you wish to combine.
#
# Simply run the cell below to import the tables from the database as DataFrames.

# %%
cards_df = pd.read_csv('cards.csv')
dust_df = pd.read_csv('dust.csv')
entourages_df = pd.read_csv('entourages.csv')
mechanics_df = pd.read_csv('mechanics.csv')
play_requirements_df = pd.read_csv('play_requirements.csv')

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes you created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since you are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index(cards_df['card_id'], inplace=True)
dust_df.set_index(dust_df['card_id'], inplace=True)
entourages_df.set_index(entourages_df['card_id'], inplace=True)
mechanics_df.set_index(mechanics_df['card_id'], inplace=True)
play_requirements_df.set_index(play_requirements_df['card_id'], inplace=True)

# %% [markdown]
# ## Executing Joins
#
# Now that you have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='images/joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table you are working with, and the right table is the table you want to join to the table you are working with.  You'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table you want to join with, `mechanics_df`
# * The `how` parameter set to the type of join you want, `'inner'`

# %%
cards_with_mechanics_df = pd.concat([cards_df, mechanics_df], ignore_index=False, join='inner')
cards_with_mechanics_df
# Out:
#                                        card_id
# card_id
# KARA_00_07                          KARA_00_07
# NEW1_008a                            NEW1_008a
# BRM_010t2                            BRM_010t2
# AT_132                                  AT_132
# OG_141                                  OG_141
# CRED_17                                CRED_17
# OG_337e                                OG_337e
# BRMA08_1H                            BRMA08_1H
# GVG_011a                              GVG_011a
# NAX8_02H_TB                        NAX8_02H_TB
# AT_131                                  AT_131
# CS2_122e                              CS2_122e
# LOEA05_02ha                        LOEA05_02ha
# CS2_102_H1_AT_132            CS2_102_H1_AT_132
# CFM_334e                              CFM_334e
# EX1_583                                EX1_583
# TB_PickYourFate_11rand  TB_PickYourFate_11rand
# LOE_007t                              LOE_007t
# CFM_095                                CFM_095
# BRM_018                                BRM_018
# PRO_001a                              PRO_001a
# BRMA10_5H                            BRMA10_5H
# BRMA11_1                              BRMA11_1
# OG_027                                  OG_027
# NAX1_01                                NAX1_01
# GVG_030                                GVG_030
# CFM_094                                CFM_094
# DS1h_292_H1                        DS1h_292_H1
# CS2_227                                CS2_227
# KAR_062                                KAR_062
# ...                                        ...
# EX1_284                                EX1_284
# LOE_038                                LOE_038
# AT_083                                  AT_083
# TB_CoOpv3_BOSS2e              TB_CoOpv3_BOSS2e
# GVG_009                                GVG_009
# CFM_338                                CFM_338
# GVG_097                                GVG_097
# GVG_097                                GVG_097
# CFM_852                                CFM_852
# LOE_020                                LOE_020
# CFM_781                                CFM_781
# GVG_090                                GVG_090
# GVG_120                                GVG_120
# EX1_055o                              EX1_055o
# CFM_321                                CFM_321
# EX1_082                                EX1_082
# FP1_017                                FP1_017
# FP1_001                                FP1_001
# AT_089                                  AT_089
# CFM_646                                CFM_646
# AT_084                                  AT_084
# OG_044a                                OG_044a
# OG_044a                                OG_044a
# LOEA09_3d                            LOEA09_3d
# BRMA13_4                              BRMA13_4
# EX1_009                                EX1_009
# BRMA10_3                              BRMA10_3
# NAX3_02H                              NAX3_02H
# AT_083e                                AT_083e
# CS2_031                                CS2_031
#
# [3898 rows x 1 columns]

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads you displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# First performed an inner join, which only includes records that are present in both tables.  Although there were 2819 records in the left table, there were only 1079 records that existed in both tables, which are what you see in the resulting dataframe.
#
# ## Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = pd.concat([cards_with_mechanics_df, play_requirements_df], ignore_index=False, join='left')
left_join_df
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-24-97f1b0a9d79a> in <module>()
# ----> 1 left_join_df = pd.concat([cards_with_mechanics_df, play_requirements_df], ignore_index=False, join='left')
#       2 left_join_df
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     246             self.intersect = True
#     247         else:  # pragma: no cover
# --> 248             raise ValueError('Only can inner (intersect) or outer (union) '
#     249                              'join the other axis')
#     250
#
# ValueError: Only can inner (intersect) or outer (union) join the other axis

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if you were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
# Every record from `cards_with_mechanics_df`, as well as any records from `play_requirements_df` that have matching index values with a record from the left table.
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = pd.concat([cards_df, dust_df], ignore_index=False, join='outer')
outer_join_df
# Out:
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#                                    action  attack                 card_id  \
# card_id
# KARA_00_07                            NaN     NaN              KARA_00_07
# NEW1_008a                             NaN     NaN               NEW1_008a
# BRM_010t2                             NaN     2.0               BRM_010t2
# AT_132                                NaN     6.0                  AT_132
# OG_141                                NaN    10.0                  OG_141
# CRED_17                               NaN     9.0                 CRED_17
# OG_337e                               NaN     NaN                 OG_337e
# BRMA08_1H                             NaN     NaN               BRMA08_1H
# GVG_011a                              NaN     NaN                GVG_011a
# NAX8_02H_TB                           NaN     NaN             NAX8_02H_TB
# AT_131                                NaN     3.0                  AT_131
# CS2_122e                              NaN     NaN                CS2_122e
# LOEA05_02ha                           NaN     NaN             LOEA05_02ha
# CS2_102_H1_AT_132                     NaN     NaN       CS2_102_H1_AT_132
# CFM_334e                              NaN     NaN                CFM_334e
# EX1_583                               NaN     5.0                 EX1_583
# TB_PickYourFate_11rand                NaN     NaN  TB_PickYourFate_11rand
# LOE_007t                              NaN     NaN                LOE_007t
# CFM_095                               NaN     1.0                 CFM_095
# BRM_018                               NaN     5.0                 BRM_018
# PRO_001a                              NaN     NaN                PRO_001a
# BRMA10_5H                             NaN     7.0               BRMA10_5H
# BRMA11_1                              NaN     NaN                BRMA11_1
# OG_027                                NaN     NaN                  OG_027
# NAX1_01                               NaN     NaN                 NAX1_01
# GVG_030                               NaN     2.0                 GVG_030
# CFM_094                               NaN     NaN                 CFM_094
# DS1h_292_H1                           NaN     NaN             DS1h_292_H1
# CS2_227                               NaN     7.0                 CS2_227
# KAR_062                               NaN     1.0                 KAR_062
# ...                                   ...     ...                     ...
# tt_010a                 DISENCHANT_NORMAL     NaN                 tt_010a
# tt_010a                 DISENCHANT_GOLDEN     NaN                 tt_010a
# EX1_559                   CRAFTING_NORMAL     NaN                 EX1_559
# EX1_559                   CRAFTING_GOLDEN     NaN                 EX1_559
# EX1_559                 DISENCHANT_NORMAL     NaN                 EX1_559
# EX1_559                 DISENCHANT_GOLDEN     NaN                 EX1_559
# EX1_624                   CRAFTING_NORMAL     NaN                 EX1_624
# EX1_624                   CRAFTING_GOLDEN     NaN                 EX1_624
# EX1_624                 DISENCHANT_NORMAL     NaN                 EX1_624
# EX1_624                 DISENCHANT_GOLDEN     NaN                 EX1_624
# OG_044a                   CRAFTING_NORMAL     NaN                 OG_044a
# OG_044a                   CRAFTING_GOLDEN     NaN                 OG_044a
# OG_044a                 DISENCHANT_NORMAL     NaN                 OG_044a
# OG_044a                 DISENCHANT_GOLDEN     NaN                 OG_044a
# AT_044                    CRAFTING_NORMAL     NaN                  AT_044
# AT_044                    CRAFTING_GOLDEN     NaN                  AT_044
# AT_044                  DISENCHANT_NORMAL     NaN                  AT_044
# AT_044                  DISENCHANT_GOLDEN     NaN                  AT_044
# EX1_345t                  CRAFTING_NORMAL     NaN                EX1_345t
# EX1_345t                  CRAFTING_GOLDEN     NaN                EX1_345t
# EX1_345t                DISENCHANT_NORMAL     NaN                EX1_345t
# EX1_345t                DISENCHANT_GOLDEN     NaN                EX1_345t
# EX1_009                   CRAFTING_NORMAL     NaN                 EX1_009
# EX1_009                   CRAFTING_GOLDEN     NaN                 EX1_009
# EX1_009                 DISENCHANT_NORMAL     NaN                 EX1_009
# EX1_009                 DISENCHANT_GOLDEN     NaN                 EX1_009
# CS2_031                   CRAFTING_NORMAL     NaN                 CS2_031
# CS2_031                   CRAFTING_GOLDEN     NaN                 CS2_031
# CS2_031                 DISENCHANT_NORMAL     NaN                 CS2_031
# CS2_031                 DISENCHANT_GOLDEN     NaN                 CS2_031
#
#                         collectible    cost  durability faction  \
# card_id
# KARA_00_07                      NaN     1.0         NaN     NaN
# NEW1_008a                       NaN     0.0         NaN     NaN
# BRM_010t2                       NaN     3.0         NaN     NaN
# AT_132                          1.0     6.0         NaN     NaN
# OG_141                          1.0    10.0         NaN     NaN
# CRED_17                         NaN     9.0         NaN     NaN
# OG_337e                         NaN     NaN         NaN     NaN
# BRMA08_1H                       NaN     NaN         NaN     NaN
# GVG_011a                        NaN     NaN         NaN     NaN
# NAX8_02H_TB                     NaN     2.0         NaN     NaN
# AT_131                          1.0     3.0         NaN     NaN
# CS2_122e                        NaN     NaN         NaN     NaN
# LOEA05_02ha                     NaN     0.0         NaN     NaN
# CS2_102_H1_AT_132               NaN     2.0         NaN     NaN
# CFM_334e                        NaN     NaN         NaN     NaN
# EX1_583                         1.0     6.0         NaN     NaN
# TB_PickYourFate_11rand          NaN     0.0         NaN     NaN
# LOE_007t                        NaN     2.0         NaN     NaN
# CFM_095                         1.0     1.0         NaN     NaN
# BRM_018                         1.0     5.0         NaN     NaN
# PRO_001a                        NaN     4.0         NaN     NaN
# BRMA10_5H                       NaN     4.0         NaN     NaN
# BRMA11_1                        NaN     NaN         NaN     NaN
# OG_027                          1.0     1.0         NaN     NaN
# NAX1_01                         NaN     NaN         NaN     NaN
# GVG_030                         1.0     2.0         NaN     NaN
# CFM_094                         1.0     6.0         NaN     NaN
# DS1h_292_H1                     NaN     2.0         NaN     NaN
# CS2_227                         1.0     5.0         NaN   HORDE
# KAR_062                         1.0     2.0         NaN     NaN
# ...                             ...     ...         ...     ...
# tt_010a                         NaN   100.0         NaN     NaN
# tt_010a                         NaN   400.0         NaN     NaN
# EX1_559                         NaN  1600.0         NaN     NaN
# EX1_559                         NaN  3200.0         NaN     NaN
# EX1_559                         NaN   400.0         NaN     NaN
# EX1_559                         NaN  1600.0         NaN     NaN
# EX1_624                         NaN   100.0         NaN     NaN
# EX1_624                         NaN   800.0         NaN     NaN
# EX1_624                         NaN    20.0         NaN     NaN
# EX1_624                         NaN   100.0         NaN     NaN
# OG_044a                         NaN    40.0         NaN     NaN
# OG_044a                         NaN   400.0         NaN     NaN
# OG_044a                         NaN     5.0         NaN     NaN
# OG_044a                         NaN    50.0         NaN     NaN
# AT_044                          NaN   400.0         NaN     NaN
# AT_044                          NaN  1600.0         NaN     NaN
# AT_044                          NaN   100.0         NaN     NaN
# AT_044                          NaN   400.0         NaN     NaN
# EX1_345t                        NaN   400.0         NaN     NaN
# EX1_345t                        NaN  1600.0         NaN     NaN
# EX1_345t                        NaN   100.0         NaN     NaN
# EX1_345t                        NaN   400.0         NaN     NaN
# EX1_009                         NaN   100.0         NaN     NaN
# EX1_009                         NaN   800.0         NaN     NaN
# EX1_009                         NaN    20.0         NaN     NaN
# EX1_009                         NaN   100.0         NaN     NaN
# CS2_031                         NaN    40.0         NaN     NaN
# CS2_031                         NaN   400.0         NaN     NaN
# CS2_031                         NaN     5.0         NaN     NaN
# CS2_031                         NaN    50.0         NaN     NaN
#
#                                                                    flavor  \
# card_id
# KARA_00_07                                                            NaN
# NEW1_008a                                                             NaN
# BRM_010t2                                                             NaN
# AT_132                  It's like putting racing stripes and a giant s...
# OG_141                  Rejected names: Forty-Foot Faceless, Big ol' N...
# CRED_17                                                               NaN
# OG_337e                                                               NaN
# BRMA08_1H                                                             NaN
# GVG_011a                                                              NaN
# NAX8_02H_TB                                                           NaN
# AT_131                             HATES being called "the wonder twins".
# CS2_122e                                                              NaN
# LOEA05_02ha                                                           NaN
# CS2_102_H1_AT_132                                                     NaN
# CFM_334e                                                              NaN
# EX1_583                 If she threatens to "moon" you, it's not what ...
# TB_PickYourFate_11rand                                                NaN
# LOE_007t                                                              NaN
# CFM_095                 He's the reason the First Bank of Gadgetzan ha...
# BRM_018                 Everybody wants someone to snuggle with. Even ...
# PRO_001a                                                              NaN
# BRMA10_5H                                                             NaN
# BRMA11_1                                                              NaN
# OG_027                  So you say you want an evolution. Well, you kn...
# NAX1_01                                                               NaN
# GVG_030                 It's adorable! AND OH MY GOODNESS WHY IS IT EA...
# CFM_094                 Kazakus has a squad of imps bottling Felfire r...
# DS1h_292_H1                                                           NaN
# CS2_227                            No Job is too big.  No fee is too big.
# KAR_062                 She can tell you all about the history of peop...
# ...                                                                   ...
# tt_010a                                                               NaN
# tt_010a                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
#
#                         health  \
# card_id
# KARA_00_07                 NaN
# NEW1_008a                  NaN
# BRM_010t2                  5.0
# AT_132                     3.0
# OG_141                    10.0
# CRED_17                    9.0
# OG_337e                    NaN
# BRMA08_1H                 50.0
# GVG_011a                   NaN
# NAX8_02H_TB                NaN
# AT_131                     4.0
# CS2_122e                   NaN
# LOEA05_02ha                NaN
# CS2_102_H1_AT_132          NaN
# CFM_334e                   NaN
# EX1_583                    4.0
# TB_PickYourFate_11rand     NaN
# LOE_007t                   NaN
# CFM_095                    1.0
# BRM_018                    5.0
# PRO_001a                   NaN
# BRMA10_5H                  7.0
# BRMA11_1                  30.0
# OG_027                     NaN
# NAX1_01                   30.0
# GVG_030                    2.0
# CFM_094                    NaN
# DS1h_292_H1                NaN
# CS2_227                    6.0
# KAR_062                    3.0
# ...                        ...
# tt_010a                    NaN
# tt_010a                    NaN
# EX1_559                    NaN
# EX1_559                    NaN
# EX1_559                    NaN
# EX1_559                    NaN
# EX1_624                    NaN
# EX1_624                    NaN
# EX1_624                    NaN
# EX1_624                    NaN
# OG_044a                    NaN
# OG_044a                    NaN
# OG_044a                    NaN
# OG_044a                    NaN
# AT_044                     NaN
# AT_044                     NaN
# AT_044                     NaN
# AT_044                     NaN
# EX1_345t                   NaN
# EX1_345t                   NaN
# EX1_345t                   NaN
# EX1_345t                   NaN
# EX1_009                    NaN
# EX1_009                    NaN
# EX1_009                    NaN
# EX1_009                    NaN
# CS2_031                    NaN
# CS2_031                    NaN
# CS2_031                    NaN
# CS2_031                    NaN
#
#                                                               how_to_earn  \
# card_id
# KARA_00_07                                                            NaN
# NEW1_008a                                                             NaN
# BRM_010t2                                                             NaN
# AT_132                                                                NaN
# OG_141                                                                NaN
# CRED_17                                                               NaN
# OG_337e                                                               NaN
# BRMA08_1H                                                             NaN
# GVG_011a                                                              NaN
# NAX8_02H_TB                                                           NaN
# AT_131                                                                NaN
# CS2_122e                                                              NaN
# LOEA05_02ha                                                           NaN
# CS2_102_H1_AT_132                                                     NaN
# CFM_334e                                                              NaN
# EX1_583                                                               NaN
# TB_PickYourFate_11rand                                                NaN
# LOE_007t                                                              NaN
# CFM_095                                                               NaN
# BRM_018                 Unlocked in Blackrock Spire, in the Blackrock ...
# PRO_001a                                                              NaN
# BRMA10_5H                                                             NaN
# BRMA11_1                                                              NaN
# OG_027                                                                NaN
# NAX1_01                                                               NaN
# GVG_030                                                               NaN
# CFM_094                                                               NaN
# DS1h_292_H1                                                           NaN
# CS2_227                                                               NaN
# KAR_062                  Unlocked in the Spire, in One Night in Karazhan.
# ...                                                                   ...
# tt_010a                                                               NaN
# tt_010a                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
#
#                                                        how_to_earn_golden  \
# card_id
# KARA_00_07                                                            NaN
# NEW1_008a                                                             NaN
# BRM_010t2                                                             NaN
# AT_132                                                                NaN
# OG_141                                                                NaN
# CRED_17                                                               NaN
# OG_337e                                                               NaN
# BRMA08_1H                                                             NaN
# GVG_011a                                                              NaN
# NAX8_02H_TB                                                           NaN
# AT_131                                                                NaN
# CS2_122e                                                              NaN
# LOEA05_02ha                                                           NaN
# CS2_102_H1_AT_132                                                     NaN
# CFM_334e                                                              NaN
# EX1_583                                                               NaN
# TB_PickYourFate_11rand                                                NaN
# LOE_007t                                                              NaN
# CFM_095                                                               NaN
# BRM_018                 Crafting unlocked in Blackrock Spire, in the B...
# PRO_001a                                                              NaN
# BRMA10_5H                                                             NaN
# BRMA11_1                                                              NaN
# OG_027                                                                NaN
# NAX1_01                                                               NaN
# GVG_030                                                               NaN
# CFM_094                                                               NaN
# DS1h_292_H1                                                           NaN
# CS2_227                                                               NaN
# KAR_062                 Crafting unlocked in the Spire, in One Night i...
# ...                                                                   ...
# tt_010a                                                               NaN
# tt_010a                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
#
#                                            name player_class        race  \
# card_id
# KARA_00_07                        Astral Portal         MAGE         NaN
# NEW1_008a                     Ancient Teachings        DRUID         NaN
# BRM_010t2                    Druid of the Flame        DRUID       BEAST
# AT_132                       Justicar Trueheart      NEUTRAL         NaN
# OG_141                        Faceless Behemoth      NEUTRAL         NaN
# CRED_17                               Rob Pardo      NEUTRAL         NaN
# OG_337e                      Eve of Destruction      NEUTRAL         NaN
# BRMA08_1H                    General Drakkisath      NEUTRAL         NaN
# GVG_011a                             Shrink Ray      NEUTRAL         NaN
# NAX8_02H_TB                             Harvest      NEUTRAL         NaN
# AT_131                           Eydis Darkbane      NEUTRAL         NaN
# CS2_122e                               Enhanced      NEUTRAL         NaN
# LOEA05_02ha                 Trogg Hate Minions!      NEUTRAL         NaN
# CS2_102_H1_AT_132                      Tank Up!      WARRIOR         NaN
# CFM_334e                              Smuggling      NEUTRAL         NaN
# EX1_583                      Priestess of Elune      NEUTRAL         NaN
# TB_PickYourFate_11rand       Dire Fate: Murlocs      NEUTRAL         NaN
# LOE_007t                                Cursed!      WARLOCK         NaN
# CFM_095                         Weasel Tunneler      NEUTRAL       BEAST
# BRM_018                          Dragon Consort      PALADIN      DRAGON
# PRO_001a                            I Am Murloc      NEUTRAL         NaN
# BRMA10_5H                       Chromatic Drake      NEUTRAL      DRAGON
# BRMA11_1                Vaelastrasz the Corrupt      NEUTRAL         NaN
# OG_027                                   Evolve       SHAMAN         NaN
# NAX1_01                             Anub'Rekhan      NEUTRAL         NaN
# GVG_030                       Anodized Robo Cub        DRUID  MECHANICAL
# CFM_094                          Felfire Potion      WARLOCK         NaN
# DS1h_292_H1                         Steady Shot       HUNTER         NaN
# CS2_227                   Venture Co. Mercenary      NEUTRAL         NaN
# KAR_062                   Netherspite Historian      NEUTRAL         NaN
# ...                                         ...          ...         ...
# tt_010a                                     NaN          NaN         NaN
# tt_010a                                     NaN          NaN         NaN
# EX1_559                                     NaN          NaN         NaN
# EX1_559                                     NaN          NaN         NaN
# EX1_559                                     NaN          NaN         NaN
# EX1_559                                     NaN          NaN         NaN
# EX1_624                                     NaN          NaN         NaN
# EX1_624                                     NaN          NaN         NaN
# EX1_624                                     NaN          NaN         NaN
# EX1_624                                     NaN          NaN         NaN
# OG_044a                                     NaN          NaN         NaN
# OG_044a                                     NaN          NaN         NaN
# OG_044a                                     NaN          NaN         NaN
# OG_044a                                     NaN          NaN         NaN
# AT_044                                      NaN          NaN         NaN
# AT_044                                      NaN          NaN         NaN
# AT_044                                      NaN          NaN         NaN
# AT_044                                      NaN          NaN         NaN
# EX1_345t                                    NaN          NaN         NaN
# EX1_345t                                    NaN          NaN         NaN
# EX1_345t                                    NaN          NaN         NaN
# EX1_345t                                    NaN          NaN         NaN
# EX1_009                                     NaN          NaN         NaN
# EX1_009                                     NaN          NaN         NaN
# EX1_009                                     NaN          NaN         NaN
# EX1_009                                     NaN          NaN         NaN
# CS2_031                                     NaN          NaN         NaN
# CS2_031                                     NaN          NaN         NaN
# CS2_031                                     NaN          NaN         NaN
# CS2_031                                     NaN          NaN         NaN
#
#                            rarity         set targeting_arrow_text  \
# card_id
# KARA_00_07                    NaN        KARA                  NaN
# NEW1_008a                     NaN     EXPERT1                  NaN
# BRM_010t2                  COMMON         BRM                  NaN
# AT_132                  LEGENDARY         TGT                  NaN
# OG_141                     COMMON          OG                  NaN
# CRED_17                 LEGENDARY     CREDITS                  NaN
# OG_337e                       NaN          OG                  NaN
# BRMA08_1H                     NaN         BRM                  NaN
# GVG_011a                      NaN         GVG                  NaN
# NAX8_02H_TB                   NaN          TB                  NaN
# AT_131                  LEGENDARY         TGT                  NaN
# CS2_122e                      NaN        CORE                  NaN
# LOEA05_02ha                   NaN         LOE                  NaN
# CS2_102_H1_AT_132             NaN  HERO_SKINS                  NaN
# CFM_334e                      NaN       GANGS                  NaN
# EX1_583                    COMMON     EXPERT1                  NaN
# TB_PickYourFate_11rand        NaN          TB                  NaN
# LOE_007t                      NaN         LOE                  NaN
# CFM_095                      EPIC       GANGS                  NaN
# BRM_018                      RARE         BRM                  NaN
# PRO_001a                      NaN       PROMO                  NaN
# BRMA10_5H                     NaN         BRM                  NaN
# BRMA11_1                      NaN         BRM                  NaN
# OG_027                       RARE          OG                  NaN
# NAX1_01                       NaN        NAXX                  NaN
# GVG_030                    COMMON         GVG                  NaN
# CFM_094                      RARE       GANGS                  NaN
# DS1h_292_H1                  FREE  HERO_SKINS                  NaN
# CS2_227                    COMMON     EXPERT1                  NaN
# KAR_062                    COMMON        KARA                  NaN
# ...                           ...         ...                  ...
# tt_010a                       NaN         NaN                  NaN
# tt_010a                       NaN         NaN                  NaN
# EX1_559                       NaN         NaN                  NaN
# EX1_559                       NaN         NaN                  NaN
# EX1_559                       NaN         NaN                  NaN
# EX1_559                       NaN         NaN                  NaN
# EX1_624                       NaN         NaN                  NaN
# EX1_624                       NaN         NaN                  NaN
# EX1_624                       NaN         NaN                  NaN
# EX1_624                       NaN         NaN                  NaN
# OG_044a                       NaN         NaN                  NaN
# OG_044a                       NaN         NaN                  NaN
# OG_044a                       NaN         NaN                  NaN
# OG_044a                       NaN         NaN                  NaN
# AT_044                        NaN         NaN                  NaN
# AT_044                        NaN         NaN                  NaN
# AT_044                        NaN         NaN                  NaN
# AT_044                        NaN         NaN                  NaN
# EX1_345t                      NaN         NaN                  NaN
# EX1_345t                      NaN         NaN                  NaN
# EX1_345t                      NaN         NaN                  NaN
# EX1_345t                      NaN         NaN                  NaN
# EX1_009                       NaN         NaN                  NaN
# EX1_009                       NaN         NaN                  NaN
# EX1_009                       NaN         NaN                  NaN
# EX1_009                       NaN         NaN                  NaN
# CS2_031                       NaN         NaN                  NaN
# CS2_031                       NaN         NaN                  NaN
# CS2_031                       NaN         NaN                  NaN
# CS2_031                       NaN         NaN                  NaN
#
#                                                                      text  \
# card_id
# KARA_00_07                       Summon a random <b>Legendary</b> minion.
# NEW1_008a                                                    Draw a card.
# BRM_010t2                                                             NaN
# AT_132                  <b>Battlecry:</b> Replace your starting Hero P...
# OG_141                                                                NaN
# CRED_17                 You can't start a game without this minion in ...
# OG_337e                                                  Stats increased.
# BRMA08_1H                                                             NaN
# GVG_011a                                             -2 Attack this turn.
# NAX8_02H_TB             <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...
# AT_131                  Whenever <b>you</b> target this minion with a ...
# CS2_122e                   Raid Leader is granting this minion +1 Attack.
# LOEA05_02ha             <b>Passive Hero Power</b>\n Enemy minions cost...
# CS2_102_H1_AT_132                        <b>Hero Power</b>\nGain 4 Armor.
# CFM_334e                                     +2/+2 from Smuggler's Crate.
# EX1_583                  <b>Battlecry:</b> Restore 4 Health to your hero.
# TB_PickYourFate_11rand        Turn each minion in play into a 1/1 Murloc.
# LOE_007t                While this is in your hand, take 2 damage at t...
# CFM_095                 <b>Deathrattle:</b> Shuffle this minion into y...
# BRM_018                 <b>Battlecry:</b> The next Dragon you play cos...
# PRO_001a                         Summon three, four, or five 1/1 Murlocs.
# BRMA10_5H                                                             NaN
# BRMA11_1                                                              NaN
# OG_027                  Transform your minions into random minions tha...
# NAX1_01                                                               NaN
# GVG_030                 <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...
# CFM_094                                 Deal $5 damage to all characters.
# DS1h_292_H1             <b>Hero Power</b>\nDeal $2 damage to the enemy...
# CS2_227                                       Your minions cost (3) more.
# KAR_062                 <b>Battlecry:</b> If you're holding a Dragon, ...
# ...                                                                   ...
# tt_010a                                                               NaN
# tt_010a                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_559                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# EX1_624                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# OG_044a                                                               NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# AT_044                                                                NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_345t                                                              NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# EX1_009                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
# CS2_031                                                               NaN
#
#                                type
# card_id
# KARA_00_07                    SPELL
# NEW1_008a                     SPELL
# BRM_010t2                    MINION
# AT_132                       MINION
# OG_141                       MINION
# CRED_17                      MINION
# OG_337e                 ENCHANTMENT
# BRMA08_1H                      HERO
# GVG_011a                ENCHANTMENT
# NAX8_02H_TB              HERO_POWER
# AT_131                       MINION
# CS2_122e                ENCHANTMENT
# LOEA05_02ha              HERO_POWER
# CS2_102_H1_AT_132        HERO_POWER
# CFM_334e                ENCHANTMENT
# EX1_583                      MINION
# TB_PickYourFate_11rand        SPELL
# LOE_007t                      SPELL
# CFM_095                      MINION
# BRM_018                      MINION
# PRO_001a                      SPELL
# BRMA10_5H                    MINION
# BRMA11_1                       HERO
# OG_027                        SPELL
# NAX1_01                        HERO
# GVG_030                      MINION
# CFM_094                       SPELL
# DS1h_292_H1              HERO_POWER
# CS2_227                      MINION
# KAR_062                      MINION
# ...                             ...
# tt_010a                         NaN
# tt_010a                         NaN
# EX1_559                         NaN
# EX1_559                         NaN
# EX1_559                         NaN
# EX1_559                         NaN
# EX1_624                         NaN
# EX1_624                         NaN
# EX1_624                         NaN
# EX1_624                         NaN
# OG_044a                         NaN
# OG_044a                         NaN
# OG_044a                         NaN
# OG_044a                         NaN
# AT_044                          NaN
# AT_044                          NaN
# AT_044                          NaN
# AT_044                          NaN
# EX1_345t                        NaN
# EX1_345t                        NaN
# EX1_345t                        NaN
# EX1_345t                        NaN
# EX1_009                         NaN
# EX1_009                         NaN
# EX1_009                         NaN
# EX1_009                         NaN
# CS2_031                         NaN
# CS2_031                         NaN
# CS2_031                         NaN
# CS2_031                         NaN
#
# [6859 rows x 19 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, you learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
